# %%
import pandas as pd

# %%
iphone_df = pd.read_csv("Data/iphone.csv", index_col=0)

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
#값 추가
iphone_df.loc["iPhone X"]
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
iphone_df.loc["iPhone XR"] = ["2018-10-03", 7.7, "5GB", "iOS 13.0", "Yes"]
iphone_df
#iPhone XR이 추가 됨
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes
# iPhone XR      2018-10-03    7.7  5GB  iOS 13.0     Yes

# %%
iphone_df["iPhone 7"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'iPhone 7'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-32faa0c38bf0> in <module>
# ----> 1 iphone_df["iPhone 7"]
#
# ...

# %%
iphone_df["Face ID"]
# Out:
# iPhone 7          No
# iPhone 7 Plus     No
# iPhone 8          No
# iPhone 8 Plus     No
# iPhone X         Yes
# iPhone XS        Yes
# iPhone XS Max    Yes
# iPhone XR        Yes
# Name: Face ID, dtype: object

# %%
iphone_df["제조사"] = "Apple"
iphone_df
#제조사 추가 됨
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple
# iPhone XR      2018-10-03    7.7  5GB  iOS 13.0     Yes  Apple

# %%
iphone_df["기능"] = "ㅇ"
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사 기능
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple  ㅇ
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple  ㅇ
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple  ㅇ
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple  ㅇ
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple  ㅇ
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple  ㅇ
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple  ㅇ
# iPhone XR      2018-10-03    7.7  5GB  iOS 13.0     Yes  Apple  ㅇ

# %%
iphone_df.drop("기능", axis="columns", inplace=True) #inplace False하면 원래 차트에는 삭제가 안된다. True를 무조건 쓰자.
iphone_df
#기능 column 지우기.
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple
# iPhone XR      2018-10-03    7.7  5GB  iOS 13.0     Yes  Apple

# %%
iphone_df.loc["iPhone XR"]
# Out:
# 출시일        2018-10-03
# 디스플레이             7.7
# 메모리               5GB
# 출시 버전        iOS 13.0
# Face ID           Yes
# 제조사             Apple
# Name: iPhone XR, dtype: object

# %%
iphone_df.loc["iPhone Xc"] = 1

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple
# iPhone XR      2018-10-03    7.7  5GB  iOS 13.0     Yes  Apple
# iPhone Xc               1    1.0    1         1       1      1

# %%
iphone_df.drop("iPhone Xc", axis="index", inplace=False) #row 지우기
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple
# iPhone XR      2018-10-03    7.7  5GB  iOS 13.0     Yes  Apple
